# %%
# MEILLEURS FILMS + CARACTÉRISTIQUES (version tmdb)

# %%
import pandas as pd
import numpy as np

# %%
chemin_bd = r"./bd_ignore/"

# %%
df_tmdb = pd.read_csv(chemin_bd + 'tmdb_full.csv')
# Out:
# /var/folders/2t/0mfg6g090d10lzzy264b5w300000gn/T/ipykernel_6292/2136615537.py:1: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_tmdb = pd.read_csv(chemin_bd + 'tmdb_full.csv')

# %%
df_tmdb['release_date'] = pd.to_datetime(df_tmdb['release_date'], errors='coerce')
df_tmdb['year'] = df_tmdb['release_date'].dt.year

# %%
df_tmdb.head()
# Out:
#    adult                     backdrop_path  budget  \
# 0  False  /dvQj1GBZAZirz1skEEZyWH2ZqQP.jpg       0
# 1  False                               NaN       0
# 2  False  /uJlc4aNPF3Y8yAqahJTKBwgwPVW.jpg       0
# 3  False  /hQ4pYsIbP22TMXOUdSfC2mjWrO0.jpg       0
# 4  False  /l94l89eMmFKh7na2a1u5q67VgNx.jpg       0
#
#                            genres homepage    id    imdb_id original_language  \
# 0                      ['Comedy']      NaN  3924  tt0029927                en
# 1                   ['Adventure']      NaN  6124  tt0011436                de
# 2            ['Drama', 'Romance']      NaN  8773  tt0055747                fr
# 3    ['Drama', 'Comedy', 'Crime']      NaN     2  tt0094675                fi
# 4  ['Drama', 'Comedy', 'Romance']      NaN     3  tt0092149                fi
#
#          original_title                                           overview  \
# 0               Blondie  Blondie and Dagwood are about to celebrate the...
# 1   Der Mann ohne Namen                                                NaN
# 2   L'Amour à vingt ans  Love at Twenty unites five directors from five...
# 3                 Ariel  Taisto Kasurinen is a Finnish coal miner whose...
# 4  Varjoja paratiisissa  An episode in the life of Nikander, a garbage ...
#
#    ...                spoken_languages    status  \
# 0  ...                          ['en']  Released
# 1  ...                              []  Released
# 2  ...  ['it', 'ja', 'pl', 'fr', 'de']  Released
# 3  ...                          ['fi']  Released
# 4  ...                          ['en']  Released
#
#                                              tagline  \
# 0  The favorite comic strip of millions at last o...
# 1                                                NaN
# 2               The Intimate Secrets of Young Lovers
# 3                                                NaN
# 4                                                NaN
#
#                            title  video  vote_average vote_count  \
# 0                        Blondie  False         7.214          7
# 1  Peter Voss, Thief of Millions  False         0.000          0
# 2                 Love at Twenty  False         6.700         41
# 3                          Ariel  False         7.046        248
# 4            Shadows in Paradise  False         7.182        269
#
#                            production_companies_name  \
# 0                              ['Columbia Pictures']
# 1                                                 []
# 2  ['Ulysse Productions', 'Unitec Films', 'Cinese...
# 3                      ['Villealfa Filmproductions']
# 4                      ['Villealfa Filmproductions']
#
#              production_companies_country    year
# 0                                  ['US']  1938.0
# 1                                      []  1921.0
# 2  ['', 'NZ', 'IT', 'JP', 'DE', 'PL', '']  1962.0
# 3                                  ['FI']  1988.0
# 4                                  ['FI']  1986.0
#
# [5 rows x 26 columns]

# %%
df_tmdb = df_tmdb[df_tmdb['vote_count']>100]

# %%
df_best_movies = df_tmdb.sort_values('vote_average', ascending=False)

# %%
df_best_movies.head(2)
# Out:
#        adult                     backdrop_path  budget  \
# 28236  False  /ttsFffDoso5BIqNugMoQDBI9A34.jpg       0
# 20173  False  /4IMn2EqCBb4n4r6FODOP7fJQIdi.jpg       0
#
#                          genres  \
# 28236                 ['Music']
# 20173  ['Music', 'Documentary']
#
#                                                 homepage       id     imdb_id  \
# 28236                  https://www.btsptdlivecinemas.com   939984  tt18687124
# 20173  https://www.disneyplus.com/movies/bts-permissi...  1022102  tt22010428
#
#       original_language                                     original_title  \
# 28236                ko  BTS Permission to Dance On Stage - Seoul: Live...
# 20173                ko               BTS: PERMISSION TO DANCE 온 스테이지 – LA
#
#                                                 overview  ...  \
# 28236  ‘BTS PERMISSION TO DANCE ON STAGE - SEOUL’, a ...  ...
# 20173  Purple colors the city of Los Angeles, as BTS ...  ...
#
#        spoken_languages    status tagline  \
# 28236      ['en', 'ko']  Released     NaN
# 20173      ['en', 'ko']  Released     NaN
#
#                                                    title  video  vote_average  \
# 28236  BTS Permission to Dance On Stage - Seoul: Live...   True           9.2
# 20173             BTS: Permission to Dance on Stage - LA  False           9.2
#
#       vote_count          production_companies_name  \
# 28236        108  ['HYBE', 'Big Hit Entertainment']
# 20173        141  ['HYBE', 'Big Hit Entertainment']
#
#       production_companies_country    year
# 28236                 ['KR', 'KR']  2022.0
# 20173                 ['KR', 'KR']  2022.0
#
# [2 rows x 26 columns]

# %%
#Définir les intervalles pour les périodes
bins = [0, 1950, 1970, 1990, 2000, 2010, float('inf')]
labels = ['<1950', '1950-1970', '1970-1990', '1990-2000', '2000-2010', '>2010']
df_best_movies['période'] = pd.cut(df_best_movies['year'], bins=bins, labels=labels, right=False)# Ajouter une colonne 'periode' directement

# %%
df_best_movies.columns
# Out:
# Index(['adult', 'backdrop_path', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'video', 'vote_average', 'vote_count', 'production_companies_name',
#        'production_companies_country', 'year', 'période'],
#       dtype='object')

# %%
df_best_movies = df_best_movies.drop(columns=['adult', 'backdrop_path', 'homepage', 'id', 'overview', 'poster_path','revenue', 'spoken_languages', 'status', 'tagline', 'video', 'imdb_id', 'budget', 'période', 'production_companies_country', 'popularity', 'vote_average', 'vote_count', 'popularity', 'original_title'])

# %%
# filtrer les genres
df_best_movies = df_best_movies[df_best_movies['genres'].str.contains("|".join(['Action', 'Drama', 'Comedy', 'Horror', 'Family', 'Adventure', 'Animation', 'Thriller']))]

# %%
df_best_movies['year'] = df_best_movies['year'].apply(lambda x: int(x))

# %%
df_best_movies.head()
# Out:
#                       genres original_language production_countries  \
# 93533             ['Comedy']                es               ['MX']
# 141093    ['Crime', 'Drama']                en                   []
# 194       ['Drama', 'Crime']                en               ['US']
# 232       ['Drama', 'Crime']                en               ['US']
# 218565  ['Drama', 'Fantasy']                es               ['MX']
#
#        release_date  runtime                              title  \
# 93533    2018-06-08       66  Franco Escamilla: por la anécdota
# 141093   1992-10-17      583   The Godfather Trilogy: 1901-1980
# 194      1972-03-14      175                      The Godfather
# 232      1994-09-23      142           The Shawshank Redemption
# 218565   1960-05-09       91                            Macario
#
#                   production_companies_name  year
# 93533                                    []  2018
# 141093                                   []  1992
# 194     ['Paramount', 'Alfran Productions']  1972
# 232           ['Castle Rock Entertainment']  1994
# 218565            ['Clasa Films Mundiales']  1960

# %%
def format(serie):
    #Enlever les []
    serie=serie.apply(lambda x : str(x).replace('[','').replace(']',''))
    serie=serie.apply(lambda x : str(x).replace("'",'').replace("'",''))
    return serie

# %%
df_best_movies['genres'] = format(df_best_movies['genres'])
df_best_movies['production_countries'] = format(df_best_movies['production_countries'])
df_best_movies['production_companies_name'] = format(df_best_movies['production_companies_name'])

# %%
df_best_movies
# Out:
#                                                    genres original_language  \
# 93533                                              Comedy                es
# 141093                                       Crime, Drama                en
# 194                                          Drama, Crime                en
# 232                                          Drama, Crime                en
# 218565                                     Drama, Fantasy                es
# ...                                                   ...               ...
# 5607                              Horror, Science Fiction                en
# 11044                                              Comedy                en
# 176027  Thriller, Fantasy, Romance, Horror, Science Fi...                en
# 12670                                    Horror, Thriller                en
# 216634       Adventure, Comedy, Action, Animation, Family                en
#
#        production_countries release_date  runtime  \
# 93533                    MX   2018-06-08       66
# 141093                        1992-10-17      583
# 194                      US   1972-03-14      175
# 232                      US   1994-09-23      142
# 218565                   MX   1960-05-09       91
# ...                     ...          ...      ...
# 5607                 DE, ZA   2004-08-09       87
# 11044                    US   1989-05-11       97
# 176027                   US   2010-02-27       93
# 12670                    US   1966-11-15       70
# 216634                   US   2012-06-15       91
#
#                                     title  \
# 93533   Franco Escamilla: por la anécdota
# 141093   The Godfather Trilogy: 1901-1980
# 194                         The Godfather
# 232              The Shawshank Redemption
# 218565                            Macario
# ...                                   ...
# 5607                         Dracula 3000
# 11044                     Going Overboard
# 176027         Birdemic: Shock and Terror
# 12670            Manos: The Hands of Fate
# 216634                         Foodfight!
#
#                                 production_companies_name  year
# 93533                                                      2018
# 141093                                                     1992
# 194                         Paramount, Alfran Productions  1972
# 232                             Castle Rock Entertainment  1994
# 218565                              Clasa Films Mundiales  1960
# ...                                                   ...   ...
# 5607    ApolloProMedia GmbH & Co. 1. Filmproduktion KG...  2004
# 11044       Theater Technologies, L.A. Dreams Productions  1989
# 176027                                 Moviehead Pictures  2010
# 12670                 Norm-Iris, Emerson Film Enterprises  1966
# 216634  Threshold Entertainment, C47 Productions, Natu...  2012
#
# [16623 rows x 8 columns]

# %%
df_best_movies = df_best_movies.set_index('title')

# %%
df_best_movies
# Out:
#                                                                               genres  \
# title
# Franco Escamilla: por la anécdota                                             Comedy
# The Godfather Trilogy: 1901-1980                                        Crime, Drama
# The Godfather                                                           Drama, Crime
# The Shawshank Redemption                                                Drama, Crime
# Macario                                                               Drama, Fantasy
# ...                                                                              ...
# Dracula 3000                                                 Horror, Science Fiction
# Going Overboard                                                               Comedy
# Birdemic: Shock and Terror         Thriller, Fantasy, Romance, Horror, Science Fi...
# Manos: The Hands of Fate                                            Horror, Thriller
# Foodfight!                              Adventure, Comedy, Action, Animation, Family
#
#                                   original_language production_countries  \
# title
# Franco Escamilla: por la anécdota                es                   MX
# The Godfather Trilogy: 1901-1980                 en
# The Godfather                                    en                   US
# The Shawshank Redemption                         en                   US
# Macario                                          es                   MX
# ...                                             ...                  ...
# Dracula 3000                                     en               DE, ZA
# Going Overboard                                  en                   US
# Birdemic: Shock and Terror                       en                   US
# Manos: The Hands of Fate                         en                   US
# Foodfight!                                       en                   US
#
#                                   release_date  runtime  \
# title
# Franco Escamilla: por la anécdota   2018-06-08       66
# The Godfather Trilogy: 1901-1980    1992-10-17      583
# The Godfather                       1972-03-14      175
# The Shawshank Redemption            1994-09-23      142
# Macario                             1960-05-09       91
# ...                                        ...      ...
# Dracula 3000                        2004-08-09       87
# Going Overboard                     1989-05-11       97
# Birdemic: Shock and Terror          2010-02-27       93
# Manos: The Hands of Fate            1966-11-15       70
# Foodfight!                          2012-06-15       91
#
#                                                            production_companies_name  \
# title
# Franco Escamilla: por la anécdota
# The Godfather Trilogy: 1901-1980
# The Godfather                                          Paramount, Alfran Productions
# The Shawshank Redemption                                   Castle Rock Entertainment
# Macario                                                        Clasa Films Mundiales
# ...                                                                              ...
# Dracula 3000                       ApolloProMedia GmbH & Co. 1. Filmproduktion KG...
# Going Overboard                        Theater Technologies, L.A. Dreams Productions
# Birdemic: Shock and Terror                                        Moviehead Pictures
# Manos: The Hands of Fate                         Norm-Iris, Emerson Film Enterprises
# Foodfight!                         Threshold Entertainment, C47 Productions, Natu...
#
#                                    year
# title
# Franco Escamilla: por la anécdota  2018
# The Godfather Trilogy: 1901-1980   1992
# The Godfather                      1972
# The Shawshank Redemption           1994
# Macario                            1960
# ...                                 ...
# Dracula 3000                       2004
# Going Overboard                    1989
# Birdemic: Shock and Terror         2010
# Manos: The Hands of Fate           1966
# Foodfight!                         2012
#
# [16623 rows x 7 columns]

# %%
df_best_movies = df_best_movies.transpose()

# %%
df_best_movies
# Out:
# title                     Franco Escamilla: por la anécdota  \
# genres                                               Comedy
# original_language                                        es
# production_countries                                     MX
# release_date                            2018-06-08 00:00:00
# runtime                                                  66
# production_companies_name
# year                                                   2018
#
# title                     The Godfather Trilogy: 1901-1980  \
# genres                                        Crime, Drama
# original_language                                       en
# production_countries
# release_date                           1992-10-17 00:00:00
# runtime                                                583
# production_companies_name
# year                                                  1992
#
# title                                      The Godfather  \
# genres                                      Drama, Crime
# original_language                                     en
# production_countries                                  US
# release_date                         1972-03-14 00:00:00
# runtime                                              175
# production_companies_name  Paramount, Alfran Productions
# year                                                1972
#
# title                       The Shawshank Redemption                Macario  \
# genres                                  Drama, Crime         Drama, Fantasy
# original_language                                 en                     es
# production_countries                              US                     MX
# release_date                     1994-09-23 00:00:00    1960-05-09 00:00:00
# runtime                                          142                     91
# production_companies_name  Castle Rock Entertainment  Clasa Films Mundiales
# year                                            1994                   1960
#
# title                         Cuando Sea Joven  \
# genres                         Comedy, Fantasy
# original_language                           es
# production_countries
# release_date               2022-09-14 00:00:00
# runtime                                    115
# production_companies_name            Lionsgate
# year                                      2022
#
# title                     Franco Escamilla: bienvenido al mundo  \
# genres                                                   Comedy
# original_language                                            es
# production_countries
# release_date                                2019-04-17 00:00:00
# runtime                                                      54
# production_companies_name
# year                                                       2019
#
# title                               The Godfather Part II  \
# genres                                       Drama, Crime
# original_language                                      en
# production_countries                                   US
# release_date                          1974-12-20 00:00:00
# runtime                                               202
# production_companies_name  Paramount, The Coppola Company
# year                                                 1974
#
# title                                   The Quintessential Quintuplets Movie  \
# genres                                            Animation, Comedy, Romance
# original_language                                                         ja
# production_countries                                                      JP
# release_date                                             2022-05-20 00:00:00
# runtime                                                                  136
# production_companies_name  DAX Production, Pony Canyon, Nichion, Bibury A...
# year                                                                    2022
#
# title                          Schindler's List  ...  \
# genres                      Drama, History, War  ...
# original_language                            en  ...
# production_countries                         US  ...
# release_date                1993-12-15 00:00:00  ...
# runtime                                     195  ...
# production_companies_name  Amblin Entertainment  ...
# year                                       1993  ...
#
# title                                                   Dragonball Evolution  \
# genres                     Action, Adventure, Fantasy, Science Fiction, T...
# original_language                                                         en
# production_countries                                              HK, GB, US
# release_date                                             2009-03-12 00:00:00
# runtime                                                                   85
# production_companies_name  World Film Magic, Dune Entertainment, Star Ove...
# year                                                                    2009
#
# title                                    The Hottie & The Nottie  \
# genres                                           Comedy, Romance
# original_language                                             en
# production_countries                                          US
# release_date                                 2008-02-08 00:00:00
# runtime                                                       91
# production_companies_name  Purple Pictures, Regent Entertainment
# year                                                        2008
#
# title                     Superbabies: Baby Geniuses 2               Romina  \
# genres                                  Comedy, Family     Horror, Thriller
# original_language                                   en                   es
# production_countries                        DE, GB, US                   MX
# release_date                       2004-08-27 00:00:00  2018-07-13 00:00:00
# runtime                                             88                   74
# production_companies_name
# year                                              2004                 2018
#
# title                     Box Office 3D - Il film dei film  \
# genres                                              Comedy
# original_language                                       it
# production_countries                                    IT
# release_date                           2011-09-09 00:00:00
# runtime                                                102
# production_companies_name         Mondo Home Entertainment
# year                                                  2011
#
# title                                                           Dracula 3000  \
# genres                                               Horror, Science Fiction
# original_language                                                         en
# production_countries                                                  DE, ZA
# release_date                                             2004-08-09 00:00:00
# runtime                                                                   87
# production_companies_name  ApolloProMedia GmbH & Co. 1. Filmproduktion KG...
# year                                                                    2004
#
# title                                                    Going Overboard  \
# genres                                                            Comedy
# original_language                                                     en
# production_countries                                                  US
# release_date                                         1989-05-11 00:00:00
# runtime                                                               97
# production_companies_name  Theater Technologies, L.A. Dreams Productions
# year                                                                1989
#
# title                                             Birdemic: Shock and Terror  \
# genres                     Thriller, Fantasy, Romance, Horror, Science Fi...
# original_language                                                         en
# production_countries                                                      US
# release_date                                             2010-02-27 00:00:00
# runtime                                                                   93
# production_companies_name                                 Moviehead Pictures
# year                                                                    2010
#
# title                                 Manos: The Hands of Fate  \
# genres                                        Horror, Thriller
# original_language                                           en
# production_countries                                        US
# release_date                               1966-11-15 00:00:00
# runtime                                                     70
# production_companies_name  Norm-Iris, Emerson Film Enterprises
# year                                                      1966
#
# title                                                             Foodfight!
# genres                          Adventure, Comedy, Action, Animation, Family
# original_language                                                         en
# production_countries                                                      US
# release_date                                             2012-06-15 00:00:00
# runtime                                                                   91
# production_companies_name  Threshold Entertainment, C47 Productions, Natu...
# year                                                                    2012
#
# [7 rows x 16623 columns]

# %%
df_best_movies.to_csv(chemin_bd + '/resultat/df_best_movies.csv', index_label='caractéritiques')
